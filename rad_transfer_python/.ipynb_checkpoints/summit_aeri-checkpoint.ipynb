# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import os
from glob import glob
from scipy.interpolate import interp1d
from scipy.ndimage.filters import gaussian_filter1d
from joblib import Parallel, delayed

from matplotlib.font_manager import FontProperties

# from simulate_radiances_utils import *
# %run simulate_radiances_utils.py
import urllib
# Out:
# HAPI version: 1.1.0.9.7
# To get the most up-to-date version please check http://hitran.org/hapi
# ATTENTION: Python versions of partition sums from TIPS-2017 are now available in HAPI code
#
#            It is free to use HAPI. If you use HAPI in your research or software development,
#            please cite it using the following reference:
#            R.V. Kochanov, I.E. Gordon, L.S. Rothman, P. Wcislo, C. Hill, J.S. Wilzewski,
#            HITRAN Application Programming Interface (HAPI): A comprehensive approach
#            to working with spectroscopic data, J. Quant. Spectrosc. Radiat. Transfer 177, 15-30 (2016)
#            DOI: 10.1016/j.jqsrt.2016.03.005

# %%
data_dir =  '/net/fluo/data2/groupMembers/cchristo/'
raw_aeri_data_dir = data_dir + 'aeri/aeri_noise_filtered/summit/'

# %%
file_paths = os.listdir(raw_aeri_data_dir)

# %%
ds_i = xr.open_dataset(raw_aeri_data_dir + file_paths[300])
ds_i_time = ds_i.isel(time = 0)
# Out:
# /home/cchristo/anaconda3/envs/rad_transfer/lib/python3.6/site-packages/xarray/coding/variables.py:141: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   condition |= data == fv

# %%
# ds_i.attrs

# %%
for var_name in ds_i.variables:
    try:
        print(var_name +  ' : ' + ds_i[var_name].attrs['longname'])
    except: 
        pass
# Out:
# base_time : Base time in Epoch
# wnum : Wave number in reciprocal centimeters
# time_offset : Time offset from base_time
# missingDataFlag : Logical flag indicating that a data record is missing (true/false)
# sceneMirPosEncoderMaxDrift : Maximum departure from ideal of the mirror position over the course of all contributing views.  Typically two hot, two ambient, and one scene view are examined.
# BBcavityFactor : Blackbody cavity geometry factor
# HBBtempOffset : Corrective offset for final hot blackbody average temperature
# ABBtempOffset : Corrective offset for final ambient blackbody average temperature
# HBBbottomTempWeight : Weight factor for bottom used in calculating hot blackbody temperature average
# HBBapexTempWeight : Weight factor for apex used in calculating hot blackbody temperature average
# HBBtopTempWeight : Weight factor for top used in calculating hot blackbody temperature average
# ABBbottomTempWeight : Weight factor for bottom used in calculating ambient blackbody temperature average
# ABBapexTempWeight : Weight factor for apex used in calculating ambient blackbody temperature average
# ABBtopTempWeight : Weight factor for top used in calculating ambient blackbody temperature average
# calibratedSceneID : Type of scene that has been calibrated (ASCII character as float)
# calibrationHBBtemp : Hot blackbody temperature used in calibration
# calibrationCBBtemp : Cold blackbody temperature used in calibration
# calibrationAmbientTemp : Ambient temperature used in calibration
# channelNumber : Instrument data channel number
# sceneMirPosEncoderDrift : Difference between actual and ideal motor encoder values for current view; indicative of quality of the mirror positioning.
# HBBmaxTempDiff : Maximum Temperature Difference Between HBB Thermistors
# ABBmaxTempDiff : Maximum Temperature Difference Between ABB Thermistors
# maxRoll : Maximum roll of the interferometer during scan. Roll axis is coincident with the axis of mirror rotation. Zero value indicates level.
# maxPitch : Maximum pitch of the interferometer during scan. Pitch axis is perpendicular to the axis of mirror rotation. Zero value indicates level.
# opticsCompartmentRelativeHumidity : Relative humidity measured in the optics compartment atop the interferometer.
# sceneMirrorMotorStep : Motor step value given to motor controller to achieve proper mirror positioning
# sceneMirrorAngle : Scene mirror view angle in non-negative degrees, measured clockwise looking into interferometer window.
# maxSampleStdDev : Maximum Standard Deviation in Thermistor Channels 0..7
# atmosphericPressure : Observation atmospheric pressure in AERI electronics
# interferometerEnclosureRelativeHumidity : Relative Humidity measured in the Interferometer Enclosure
# atmosphericRelativeHumidity : Relative humidity measured near Blackbodies. Use with Air Temperature Near BBs only.
# interferometerWindowTemp : Interferometer window temperature measured on the outside of the aluminum window flange
# rainSensorIntensity : Rain sensor analog output: the rain sensor is located inside the hatch near the sky aperture and is used to flag the critical condition of rain falling on the AERI sky aperture. If rain is detected, the AERI scene mirror will be safed to the down looking p
# detectorTemp : Detector temperature sensed via diode near detector
# coolerCurrent : Stirling cycle cooler current
# SCEtemp : Signal conditioning electronics inside air temperature
# motorDriverTemp : Scene mirror motor driver heat sink temperature
# computerTemp : AERI ingest computer temperature measured at back panel of computer
# rackAmbientTemp : Electronics rack ambient temperature measured at inside top of rack
# coolerPowerSupplyTemp : Stirling cooler power supply temperature measured at power supply frame
# coolerExpanderTemp : Stirling cycle cooler expander temperature
# coolerCompressorTemp : Stirling cooler compressor temperature measured at compressor heatsink
# BBcontroller2temp : Blackbody controller Unit 2 power supply temperature
# BBcontroller1temp : Blackbody controller Unit 1 power supply temperature
# fixed12KohmResistor : Resistive temperature of 12 Kohm fixed resistor located in SCE-P3 shell
# mirrorMotorTemp : Scene mirror motor case temperature
# airNearBBsTemp : Ambient air temperature near blackbodies
# BBsupportStructureTemp : Temperature of the AERI blackbody support structure
# interferometerSecondPortTemp : AERI interferometer temperature at second port
# airNearInterferometerTemp : Ambient air temperature near the interferometer
# outsideAirTemp : Ambient air temperature at hatch opening
# fixed97KohmResistor : Resistive temperature of 97 Kohm fixed resistor located in SCE-P4 shell
# fixed2500ohmResistor : Resistive temperature of 2500 Ohm fixed resistor - banana plug mounted
# HBBbottomTemp : Hot blackbody temperature - rim bottom
# HBBapexTemp : Hot blackbody temperature - apex
# HBBtopTemp : Hot blackbody temperature - rim top
# ABBbottomTemp : Ambient blackbody temperature
# ABBapexTemp : Ambient blackbody temperature - apex
# ABBtopTemp : Ambient blackbody temperature - rim top
# JulianDay : Julian Day including day and fraction of day
# sceneMirPosEncoder : Scene mirror position encoder value
# sceneMirPosCount : Number of views in a sequence
# sceneMirrorPosition : Instrument scene mirror position identifier
# coadditionsCount : Number of complete (forward+backward) interferogram scans in sample average
# sceneViewDuration : Duration of scene view
# systemReleaseNumber : Version number of Operational Software
# Altitude : Observation Altitude
# Longitude : Observation longitude
# Latitude : Observation latitude
# timeHHMMSS : Time at center of AERI sky observation period
# dateYYMMDD : Observation date
# instrumentUnitNumber : Character string containing instrument name
# AERIunitNumber : AERI instrument unit serial number
# Time : Time at center of AERI sky observation period
# mean_rad : Interferometer scan directional average of radiance
# wnum2 : Wave number in reciprocal centimeters

# %%
# ds_i['sceneMirrorPosition']
# Out:
# <xarray.DataArray 'sceneMirrorPosition' (time: 3352)>
# array([83., 84., 85., ..., 88., 89., 90.], dtype=float32)
# Coordinates:
#   * time     (time) datetime64[ns] 2011-04-17T00:03:42 ... 2011-04-17T23:56:32
# Attributes:
#     longname:   Instrument scene mirror position identifier
#     units:      count
#     precision:  1E0

# %%
file_paths_sub = [raw_aeri_data_dir + fname for fname in file_paths if '201501' in fname][:7]

# %%
ds_1 = xr.open_dataset(file_paths_sub[0])
ds_2 = xr.open_dataset(file_paths_sub[0])
# ds_i_time = ds_i.isel(time = 0)
# Out:
# /home/cchristo/anaconda3/envs/rad_transfer/lib/python3.6/site-packages/xarray/coding/variables.py:141: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   condition |= data == fv
# /home/cchristo/anaconda3/envs/rad_transfer/lib/python3.6/site-packages/xarray/coding/variables.py:141: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   condition |= data == fv

# %%
ds_1 #['mean_rad']
ds_1['time_offset']
# Out:
# <xarray.DataArray 'time_offset' (time: 3312)>
# array(['2015-01-01T00:03:40.000000000', '2015-01-01T00:03:55.000000000',
#        '2015-01-01T00:04:15.000000000', ..., '2015-01-01T23:55:36.000000000',
#        '2015-01-01T23:55:56.000000000', '2015-01-01T23:56:16.000000000'],
#       dtype='datetime64[ns]')
# Dimensions without coordinates: time
# Attributes:
#     longname:  Time offset from base_time

# %%
ds_i
# Out:
# <xarray.Dataset>
# Dimensions:   (time: 23384, wnum: 2714)
# Coordinates:
#   * wnum      (wnum) float64 491.8 492.3 492.8 ... 1.799e+03 1.799e+03 1.8e+03
#   * time      (time) datetime64[ns] 2015-01-01T00:03:40 ... 2015-01-07T23:57:11
# Data variables:
#     mean_rad  (time, wnum) float64 dask.array<chunksize=(3312, 2714), meta=np.ndarray>

# %%
def preprocess_spectra_ds(ds):
    time_offset = ds['time_offset']
#     base_time = ds['base_time']
    ds_subset = ds['mean_rad'].to_dataset()
    ds_subset = ds_subset.assign_coords({'time':time_offset})
    return ds_subset

# %%
# preprocess_spectra_ds(ds_2)
ds_2['time_offset']
# Out:
# <xarray.DataArray 'time_offset' (time: 3312)>
# array(['2015-01-01T00:03:40.000000000', '2015-01-01T00:03:55.000000000',
#        '2015-01-01T00:04:15.000000000', ..., '2015-01-01T23:55:36.000000000',
#        '2015-01-01T23:55:56.000000000', '2015-01-01T23:56:16.000000000'],
#       dtype='datetime64[ns]')
# Dimensions without coordinates: time
# Attributes:
#     longname:  Time offset from base_time

# %%
ds_i = xr.open_mfdataset(file_paths_sub, 
                         combine = 'by_coords',
                         concat_dim = 'time', 
                         preprocess=preprocess_spectra_ds)
# Out:
# /home/cchristo/anaconda3/envs/rad_transfer/lib/python3.6/site-packages/xarray/coding/variables.py:141: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   condition |= data == fv
# /home/cchristo/anaconda3/envs/rad_transfer/lib/python3.6/site-packages/xarray/coding/variables.py:141: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   condition |= data == fv
# /home/cchristo/anaconda3/envs/rad_transfer/lib/python3.6/site-packages/xarray/coding/variables.py:141: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   condition |= data == fv
# /home/cchristo/anaconda3/envs/rad_transfer/lib/python3.6/site-packages/xarray/coding/variables.py:141: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   condition |= data == fv
# /home/cchristo/anaconda3/envs/rad_transfer/lib/python3.6/site-packages/xarray/coding/variables.py:141: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   condition |= data == fv
# /home/cchristo/anaconda3/envs/rad_transfer/lib/python3.6/site-packages/xarray/coding/variables.py:141: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   condition |= data == fv
# /home/cchristo/anaconda3/envs/rad_transfer/lib/python3.6/site-packages/xarray/coding/variables.py:141: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   condition |= data == fv

# %%
ds_i_nan = ds_i.where(ds_i > 0, np.nan)
ds_i_time_max = ds_i_nan.max('time')
ds_i_time_min = ds_i_nan.min('time')
ds_i_time_median = ds_i_nan.median('time')

# %%
plt.figure(figsize = (10,7))
# ds_i
k_grid = ds_i_time['wnum'].values
rad = ds_i_time_min['mean_rad'].values
plt.plot(k_grid, rad, linewidth = 0.5, alpha=0.7)



wavenum_m = k_grid*1e2
W_m_mW_cm = 1e2*1e3
plt.plot(k_grid, W_m_mW_cm*planck_wavenumber(wavenum_m,270),label='BB @ 270K',alpha=0.63)
plt.plot(k_grid, W_m_mW_cm*planck_wavenumber(wavenum_m,260),label='BB @ 260K',alpha=0.63)
plt.plot(k_grid, W_m_mW_cm*planck_wavenumber(wavenum_m,250),label='BB @ 250K',alpha=0.63)
plt.plot(k_grid, W_m_mW_cm*planck_wavenumber(wavenum_m,240),label='BB @ 240K',alpha=0.63)
plt.plot(k_grid, W_m_mW_cm*planck_wavenumber(wavenum_m,220),label='BB @ 220K',alpha=0.63)
plt.legend(loc=0)

k_grid = ds_i_time['wnum'].values
rad = ds_i_time_max['mean_rad'].values
plt.plot(k_grid, rad, linewidth = 0.5,alpha=0.7)


k_grid = ds_i_time['wnum'].values
rad = ds_i_time_median['mean_rad'].values
plt.plot(k_grid, rad, linewidth = 0.5,alpha=0.7)

# plt.xlim((491,1799))
plt.xlim((500, 1800))

plt.grid()
plt.xlabel('Wavenumber ($cm^{-1}$)')
plt.ylabel(r'downwelling Radiance ($mW m^{-2} sr^{-1} cm^{-1}$)')
plt.title('Downwelling Thermal Radiance in Nadir at surface')
# Out:
# /home/cchristo/anaconda3/envs/rad_transfer/lib/python3.6/site-packages/xarray/coding/variables.py:141: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   condition |= data == fv
# /home/cchristo/anaconda3/envs/rad_transfer/lib/python3.6/site-packages/xarray/coding/variables.py:141: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   condition |= data == fv
# /home/cchristo/anaconda3/envs/rad_transfer/lib/python3.6/site-packages/xarray/coding/variables.py:141: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   condition |= data == fv

# %%
standard_dev_rad = ds_i_time['standard_dev_mean_rad'].values
k_grid2 = ds_i_time['wnum2'].values
# Out:
# ---------------------------------------------------------------
# KeyError                      Traceback (most recent call last)
# ~/anaconda3/envs/rad_transfer/lib/python3.6/site-packages/xarray/core/dataset.py in _construct_dataarray(self, name)
#    1163         try:
# -> 1164             variable = self._variables[name]
#    1165         except KeyError:
#
# KeyError: 'standard_dev_mean_rad'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                      Traceback (most recent call last)
# <ipython-input-140-90129a5d163f> in <module>
# ----> 1 standard_dev_rad = ds_i_time['standard_dev_mean_rad'].values
#       2 k_grid2 = ds_i_time['wnum2'].values
#
# ~/anaconda3/envs/rad_transfer/lib/python3.6/site-packages/xarray/core/dataset.py in __getitem__(self, key)
#    1252
#    1253         if hashable(key):
# -> 1254             return self._construct_dataarray(key)
#    1255         else:
#    1256             return self._copy_listed(np.asarray(key))
#
# ~/anaconda3/envs/rad_transfer/lib/python3.6/site-packages/xarray/core/dataset.py in _construct_dataarray(self, name)
#    1165         except KeyError:
#    1166             _, name, variable = _get_virtual_variable(
# -> 1167                 self._variables, name, self._level_coords, self.dims
#    1168             )
#    1169
#
# ~/anaconda3/envs/rad_transfer/lib/python3.6/site-packages/xarray/core/dataset.py in _get_virtual_variable(variables, key, level_vars, dim_sizes)
#     165         ref_var = dim_var.to_index_variable().get_level_variable(ref_name)
#     166     else:
# --> 167         ref_var = variables[ref_name]
#     168
#     169     if var_name is None:
#
# KeyError: 'standard_dev_mean_rad'

# %%
plt.plot(k_grid2, standard_dev_rad, linewidth = 0.5)

plt.xlabel('Wavenumber')
plt.ylabel('Radiance STD')
# Out:
# Text(0, 0.5, 'Radiance STD')
