# %% [markdown]
# ### Notebook to make plots with final results from saved data

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import os
from glob import glob
from scipy.interpolate import interp1d, interp2d
from scipy.ndimage.filters import gaussian_filter1d
import pandas as pd
import calendar 
from matplotlib.font_manager import FontProperties
from scipy.interpolate import CubicSpline, BSpline
from scipy.optimize import leastsq, curve_fit

# %run simulate_radiances_utils.py
# %run mean_analysis_utils.py
# %run locations.py


# font = {'weight' : 'bold',
#         'size'   : 12}
# label_fontdict = {'weight' : 'bold',
#         'size'   : 12}
# title_fontdict = {'weight' : 'bold',
#         'size'   : 12}

# matplotlib.rc('font', **font)

# %%
save_final_data_dir = '/net/fluo/data2/groupMembers/cchristo/final_results/data/'
# save_final_figs_dir = '/net/fluo/data2/groupMembers/cchristo/final_results/figs/'
save_final_figs_dir = '/home/cchristo/proj_christian/final_results/figs/'

# %%
os.listdir(save_final_data_dir)
# Out:
# ['CH4_rf_timeseries.nc',
#  'CO2_rf_timeseries.nc',
#  'CH4_eh_radiance_weighted_timeseries.nc',
#  'forcing_spectral_residual_CO2_summer_mean.nc',
#  'forcing_spectral_residual_CO2_winter_mean.nc',
#  'forcing_spectral_residual_CH4_summer_mean.nc',
#  'forcing_spectral_residual_CH4_winter_mean.nc',
#  'mean_surface_spectrum_components.nc',
#  'mean_preindust_surface_spectrum_components.nc',
#  'CO2_preindus_eh_radiance_weighted_timeseries.nc',
#  'CH4_preindus_eh_radiance_weighted_timeseries.nc',
#  'CO2_eh_radiance_weighted_timeseries.nc',
#  'CO2_eh_rf_weighted_timeseries.nc',
#  'CH4_eh_rf_weighted_timeseries.nc',
#  'seasonal_co2_ds.nc',
#  'seasonal_co2_preindust_ds.nc',
#  'seasonal_ch4_ds.nc',
#  'seasonal_ch4_preindust_ds.nc']

# %% [markdown]
# # Stefan-Boltzmann Law

# %%
T_grid = np.linspace(200, 320, 1000)
F_grid =  stefan_boltzmann(T_grid)

plt.figure(figsize = (6,5))

plt.plot(T_grid, F_grid, linewidth = 5, c = 'b')
plt.grid()
plt.xlabel('Temperature [K]', weight = 'bold')
plt.ylabel(r'Radiative Flux $[\frac{W}{m^2}]$', weight = 'bold')
plt.title('Stefan–Boltzmann Law', weight = 'bold')
plt.tight_layout()
plt.savefig(save_final_figs_dir + 'stefan_boltzmann_plot.png', dpi = 200)

# %% [markdown]
# ## Plot rf timeseries

# %%
rf_timeseries_ds_co2 = xr.open_dataset(save_final_data_dir + 'CO2_rf_timeseries.nc')
rf_timeseries_ds_ch4 = xr.open_dataset(save_final_data_dir + 'CH4_rf_timeseries.nc')

# %%
xx, yy = rf_timeseries_ds_co2['time'].values, \
         rf_timeseries_ds_co2['lw_down_total'].values
    
plt.figure(figsize = (7,6))
plt.plot(xx, yy, c = 'blue', linewidth = 0.4)
plt.gca().xaxis.grid()
plt.ylabel(r'$CO_{2}$ Forcing $[\dfrac{W}{m^{2}}]$', weight = 'bold')
plt.xlabel('Year', weight = 'bold')
plt.title('SMT $CO_{2}$ Surface Forcing', weight = 'bold')
# plt.savefig(save_final_figs_dir + 'rf_timeseries_CO2.png', dpi = 300)

xx, yy = rf_timeseries_ds_ch4['time'].values, \
         rf_timeseries_ds_ch4['lw_down_total'].values
    
plt.figure(figsize = (7,6))
plt.plot(xx, yy, c = 'r', linewidth = 0.4)
plt.gca().xaxis.grid()
plt.ylabel(r'$CH_{4}$ Forcing $[\dfrac{W}{m^{2}}]$', weight = 'bold')
plt.xlabel('Year', weight = 'bold')
plt.title('SMT $CH_{4}$ Surface Forcing', weight = 'bold')
# plt.savefig(save_final_figs_dir + 'rf_timeseries_CH4.png', dpi = 300)
# Out:
# Text(0.5, 1.0, 'SMT $CH_{4}$ Surface Forcing')

# %%
dt_index = pd.DatetimeIndex(xx)
month_ind = [(time_i.year - 2011)*12 + (time_i.month - 1) + \
             (time_i.day/calendar.monthrange(time_i.year, time_i.month)[1]) for time_i in dt_index]
# rf_timeseries_ds_co2.time

# %%
plt.plot(month_ind)

# %%
x0 = np.array([0.5, 6])
# out = leastsq(sin_func, x0, args=(month_ind, \
#                                   rf_timeseries_ds_co2['lw_down_total'].values))

out = curve_fit(sin_func, month_ind, \
                         rf_timeseries_ds_ch4['lw_down_total'].values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-c63bca18d361> in <module>
#       3 #                                   rf_timeseries_ds_co2['lw_down_total'].values))
#       4
# ----> 5 out = curve_fit(sin_func, month_ind, \
#       6                          rf_timeseries_ds_ch4['lw_down_total'].values)
#
# NameError: name 'month_ind' is not defined

# %%
out
# Out:
# (array([-0.05280398,  1.01641055]),
#  array([[3.54298150e-05, 1.73188406e-06],
#         [1.73188406e-06, 1.08559908e-05]]))

# %%
eh_timeseries_ds_co2 = xr.open_dataset(save_final_data_dir + 'CO2_eh_radiance_weighted_timeseries.nc')
eh_timeseries_ds_co2_preindust = xr.open_dataset(save_final_data_dir + 'CO2_preindus_eh_radiance_weighted_timeseries.nc')


eh_timeseries_ds_ch4 = xr.open_dataset(save_final_data_dir + 'CH4_eh_radiance_weighted_timeseries.nc')

eh_timeseries_ds_ch4_preindust = xr.open_dataset(save_final_data_dir + 'CH4_preindus_eh_radiance_weighted_timeseries.nc')

# open rf weighted CO2 + Methane
eh_rf_timeseries_ds_co2 = xr.open_dataset(save_final_data_dir + 'CO2_eh_rf_weighted_timeseries.nc')
eh_rf_timeseries_ds_ch4 = xr.open_dataset(save_final_data_dir + 'CH4_eh_rf_weighted_timeseries.nc')

# %%
# os.listdir(save_final_data_dir)

# %%
# eh_timeseries_ds_co2.max()
# eh_timeseries_ds_co2['__xarray_dataarray_variable__'].plot()

# %%
# 'CO2_preindus_eh_radiance_weighted_timeseries.nc'

xx, yy = eh_timeseries_ds_co2['time'].values, \
         eh_timeseries_ds_co2['__xarray_dataarray_variable__'].values
# xx2, yy2 = eh_timeseries_ds_co2_preindust['time'].values, \
#          eh_timeseries_ds_co2_preindust['__xarray_dataarray_variable__'].values
    
#12,6
plt.figure(figsize = (7,6))
plt.plot(xx, yy, c = 'b', linewidth = 0.5, label = '395 ppm')
# plt.plot(xx2, yy2, c = 'lightblue', alpha = 0.8, linewidth = 0.5, label = '280 ppm')
plt.gca().xaxis.grid()
plt.ylabel(r' $\tau = 1$ Height [m]', weight = 'bold')
plt.xlabel('Year', weight = 'bold')
plt.title('$CO_2$ Radiance Weighted Emission Height', weight = 'bold')
# plt.legend()
plt.savefig(save_final_figs_dir + 'r_weighted_e_height_co2_current_only.png', dpi = 300)

# plt.figure(figsize = (12,6))
# plt.plot(xx, yy - yy2, '--', c = 'r', linewidth = 0.4)
# plt.gca().xaxis.grid()
# plt.ylabel(r' $\Delta$ $(\tau = 1)$ Height [m]', weight = 'bold')
# plt.xlabel('Year', weight = 'bold')
# plt.title('$CO_2 \Delta$ Radiance Weighted Emission Height', weight = 'bold')

# xx, yy = eh_timeseries_ds_ch4['time'].values, \
#          eh_timeseries_ds_ch4['__xarray_dataarray_variable__'].values
    
# xx2, yy2 = eh_timeseries_ds_ch4_preindust['time'].values, \
#          eh_timeseries_ds_ch4_preindust['__xarray_dataarray_variable__'].values
    
    
# plt.figure(figsize = (7,6))
# plt.plot(xx, yy, c = 'r', linewidth = 0.5, label = '1.89 ppm')
# plt.plot(xx2, yy2, c = 'lightcoral', linewidth = 0.5, label = '0.722 ppm')
# plt.gca().xaxis.grid()
# plt.ylabel(r'  $\tau = 1$ Height [m]', weight = 'bold')
# plt.xlabel('Year', weight = 'bold')
# plt.title('$CH_4$ Radiance Weighted Emission Height', weight = 'bold')
# plt.legend()
# plt.savefig(save_final_figs_dir + 'r_weighted_e_height_ch4.png', dpi = 300)




# xx, yy = eh_rf_timeseries_ds_co2['time'].values, \
#          eh_rf_timeseries_ds_co2['__xarray_dataarray_variable__'].values
# xx22, yy22 = eh_rf_timeseries_ds_ch4['time'].values, \
#          eh_rf_timeseries_ds_ch4['__xarray_dataarray_variable__'].values

# plt.figure(figsize = (7,6))
# plt.plot(xx, yy, c = 'b', alpha = 0.8, linewidth = 0.5, label = 'CO2')
# plt.plot(xx22, yy22, c = 'r', alpha = 0.8, linewidth = 0.5, label = 'CH4')
# plt.gca().xaxis.grid()
# plt.ylabel(r' $\tau = 1$ Height [m]', weight = 'bold')
# plt.xlabel('Year', weight = 'bold')
# plt.title('$CO_2$,$CH_4$ Forcing Residual Weighted Emission Height', weight = 'bold')
# plt.legend()
# plt.savefig(save_final_figs_dir + 'rf_resid_weighted_e_height_both.png', dpi = 300)



# plt.figure(figsize = (7,6))
# plt.plot(xx, yy, c = 'b', linewidth = 0.5)
# plt.gca().xaxis.grid()
# plt.ylabel(r'  $\tau = 1$ Height [m]', weight = 'bold')
# plt.xlabel('Year', weight = 'bold')
# plt.title('$CO_2$ Emission Height Weighted by Forcing Residual ', weight = 'bold')
# plt.legend()
# plt.savefig(save_final_figs_dir + 'rf_resid_weighted_e_height_co2_only.png', dpi = 300)

# %%
# plt.plot(yy - yy2)

# %%
# np.mean(yy - yy2)

# %%
os.listdir(save_final_data_dir)
# Out:
# ['CH4_rf_timeseries.nc',
#  'CO2_rf_timeseries.nc',
#  'CO2_eh_radiance_weighted_timeseries.nc',
#  'CH4_eh_radiance_weighted_timeseries.nc',
#  'forcing_spectral_residual_CO2_summer_mean.nc',
#  'forcing_spectral_residual_CO2_winter_mean.nc']

# %% [markdown]
# ## Seasonally Averaged Spectral Residual Plot

# %%
co2_spec_resid_summer = xr.open_dataset(save_final_data_dir + 'forcing_spectral_residual_CO2_summer_mean.nc')
co2_spec_resid_winter =  xr.open_dataset(save_final_data_dir + 'forcing_spectral_residual_CO2_winter_mean.nc')


ch4_spec_resid_summer = xr.open_dataset(save_final_data_dir + 'forcing_spectral_residual_CH4_summer_mean.nc')
ch4_spec_resid_winter =  xr.open_dataset(save_final_data_dir + 'forcing_spectral_residual_CH4_winter_mean.nc')

# %%
spec_resid_summer['lw_down_ta']
# Out:
# <xarray.Dataset>
# Dimensions:        (nu: 130806)
# Coordinates:
#   * nu             (nu) float64 491.8 491.8 491.8 ... 1.8e+03 1.8e+03 1.8e+03
#     season         object ...
# Data variables:
#     lw_down_total  (nu) float64 ...

# %%
# co2_spec_resid_summer.nu.values.min()
rr = co2_spec_resid_summer['lw_down_total'].values

np.where(rr>0,rr, np.nan)
# Out:
# array([7.76677477e-06, 7.05749505e-06, 6.18549195e-06, ...,
#        7.08148817e-14, 2.75604192e-13, 4.62802539e-14])

# %%
plt.plot(co2_spec_resid_summer['lw_down_total'].values)
plt.xlim([0, 15000])
# Out:
# (0.0, 15000.0)

# %%
# %run mean_analysis_utils.py
plot_forcing_spectral_residual(co2_spec_resid_summer['lw_down_total'].values,
                               co2_spec_resid_summer.nu.values,
                               title = r'Mean Summer $CO_2$-Forcing Spectral Residual',
                               ylims = [-1, 12],
                               xlims = [491, 1100])
plt.savefig(save_final_figs_dir + 'mean_summer_CO2_spec_resid.png', dpi = 300)

# %%
plot_forcing_spectral_residual(co2_spec_resid_winter['lw_down_total'].values,
                               co2_spec_resid_winter.nu.values,
                               r'Mean Winter $CO_2$-Forcing Spectral Residual',
                               ylims = [-1, 12],
                               xlims = [491, 1100])
plt.savefig(save_final_figs_dir + 'mean_winter_CO2_spec_resid.png', dpi = 300)

# %%
plot_forcing_spectral_residual(ch4_spec_resid_summer['lw_down_total'].values,
                               ch4_spec_resid_summer.nu.values,
                               r'Mean Summer $CH_4$-Forcing Spectral Residual',
                               ylims = [0, 7.5],
                               xlims = [1000, 1600])
plt.savefig(save_final_figs_dir + 'mean_summer_CH4_spec_resid.png', dpi = 300)

# %%
plot_forcing_spectral_residual(ch4_spec_resid_winter['lw_down_total'].values,
                               ch4_spec_resid_winter.nu.values,
                                r'Mean Winter $CH_4$-Forcing Spectral Residual',
                               ylims = [0, 7.5],
                               xlims = [1000, 1600])
plt.savefig(save_final_figs_dir + 'mean_winter_CH4_spec_resid.png', dpi = 300)

# %% [markdown]
# # Plot downwelling radiation by componenents

# %%
down_rad_components = xr.open_dataset(save_final_data_dir + 'mean_surface_spectrum_components.nc')
down_rad_components_pre = xr.open_dataset(save_final_data_dir +'mean_preindust_surface_spectrum_components.nc')

# %%
# %run simulate_radiances_utils.py
plot_downwelling_rad(down_rad_components['lw_down_CO2'].values,
                     down_rad_components['lw_down_CH4'].values,
                     down_rad_components['lw_down_H2O'].values,
                     figsize = (12,6),
                     nu = down_rad_components.nu.values)
plt.ylim([0, 90])

plt.savefig(save_final_figs_dir + 'mean_annual_downwelling_spectrum_components.png', dpi = 300)
# Out:
# No handles with labels found to put in legend.

# %%
# %run simulate_radiances_utils.py
plot_downwelling_rad(down_rad_components_pre['lw_down_CO2'].values,
                     down_rad_components_pre['lw_down_CH4'].values,
                     down_rad_components_pre['lw_down_H2O'].values,
                     nu = down_rad_components.nu.values)
plt.ylim([0, 90])
# Out:
# (0.0, 90.0)

# %%
seasonal_fields = xr.open_dataset(save_final_data_dir + 'seasonal_co2_ds.nc')
# seasonal_fields = xr.open_dataset(save_final_data_dir + 'seasonal_ch4_ds.nc')

# %%
dt_dz_winter = seasonal_fields.isel(season = 0)['dT_CO2'].values*(-1*1000)
dt_dz_summer = seasonal_fields.isel(season = 1)['dT_CO2'].values*(-1*1000)
# dt_dz_winter = seasonal_fields.isel(season = 0)['dT_CH4'].values*(-1*1000)
# dt_dz_summer = seasonal_fields.isel(season = 1)['dT_CH4'].values*(-1*1000)



nu_ = seasonal_fields['nu'].values

# %%
# np.nanmean(dt_dz_winter[dt_dz_winter>0])

# %%
np.nanmean(dt_dz_summer[dt_dz_summer>0])
# Out:
# /home/cchristo/anaconda3/envs/rad_transfer/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in greater
#   """Entry point for launching an IPython kernel.
# 4.550058559072953

# %%
plt.figure(figsize = (7,5))
plt.plot(nu_, dt_dz_winter, c = 'b', linewidth = 0.5, label = 'Winter')
plt.plot(nu_, dt_dz_summer, 
         c = 'r', linewidth = 0.5, 
         alpha = 0.7, label = 'Summer')
plt.legend()
plt.grid()
plt.xlabel(r'Wavenumber $[cm^{-1}]$', weight = 'bold')
plt.ylabel(r'Lapse Rate at $\tau = 1$ $[\frac{K}{km}]$', weight = 'bold')
plt.title('Lapse Rate at Emission Height for $CH_4$', weight = 'bold')
# plt.xlim([570, 800])
# plt.savefig(save_final_figs_dir + 'lapse_rate_spec_ch4.png', dpi = 300)
plt.xlim([600, 610])
# plt.xlim([1306, 1307])
# Out:
# (600.0, 610.0)

# %%
seasonal_fields.isel(season = 0)['eh_CH4'].plot()
# plt.ylim([0, 400])
plt.grid()
plt.xlim([1306, 1307])
plt.ylim([0, 300])
# Out:
# (0.0, 300.0)
