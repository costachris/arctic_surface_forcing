# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import os
from scipy.interpolate import interp1d

## The usual packages (numpy, matplotlib, etc)
# Import HAPI interface
from hapi import *

import pandas as pd


from matplotlib.font_manager import FontProperties


font = {'weight' : 'bold',
        'size'   : 22}
label_fontdict = {'weight' : 'bold',
        'size'   : 22}
title_fontdict = {'weight' : 'bold',
        'size'   : 21}

matplotlib.rc('font', **font)

# %%
reanalysis_data_dir = '/export/data1/cchristo/profile_timeseries/'

# %%
os.listdir(reanalysis_data_dir )
# Out:
# ['SGP_ts_2015.nc',
#  'brazil_ts_2015.nc',
#  'central_pacific_ts_2015.nc',
#  'north_slope_ts_2015.nc',
#  'summit_ts_2015.nc']

# %%
profile_ds = xr.open_dataset(reanalysis_data_dir  + 'summit_ts_2015.nc')
profile_ds.load()
profile_ds['t'] = profile_ds['t'] - 273.15

# %%
profile_ds
# Out:
# <xarray.Dataset>
# Dimensions:  (level: 37, time: 8760)
# Coordinates:
#   * level    (level) int32 1 2 3 5 7 10 20 30 ... 850 875 900 925 950 975 1000
#   * time     (time) datetime64[ns] 2015-01-01 ... 2015-12-31T23:00:00
# Data variables:
#     t        (time, level) float32 -23.756393 -42.024414 ... -6.4060974
